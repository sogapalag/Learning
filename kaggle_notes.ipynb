# %% [markdown]
# #### Tree-based
#   Lightgbm, xgboost
#
# #### non Tree-based
#   NN, Linear, k-NN
#
# Tree, NN are powerful
#
# ------------------
#
# insight of DATA!!很重要，algo和调参大多数人都行
#
# ------------------
#
# 了解feature对non-Tree-based的影响
#
#
# 预处理(sklearn.preprocessing)
#   - scale
#     - \[0,1\], or,  N(0,1)
#   - outliers
#   - scipy.stats.rankdata
#   - $\log$, $()^t$, $t=1/2$ ot $t<1$
#
# generation
#   - need prior knowledge/logic e.g. \\$3.99 取小数部分-> \\$.99
#   - EDA
#
# encoding， （无序类别，e.g 猫/狗）（有序, edu.degree）
#   - labeling，，，Tree-based
#   - frequency，无序类,,,Tree-based
#   - order
#   - one-hot，经常用于non Tree-based
#
# 时间数据feature generation
#   - 周期性，TimeSince；isHoliday，delta
#
# 坐标类
#   - 地理特征
#   - 新坐标系，便于Tree-based便于直线，而不用折线
#
# Missing Values
#   - may hidden, e.g. -1而不是用NaN；isnull只能检测NaN
#   - fillna: mean/median, sample, -999, 连续量折中 etc.
#
# Text:
#   - BagofWords: TFiDf
#   - N-gram: N个连续词为新feature
#   - lowercase, lemmtization, stopwords, stem
#   - Embedding
#   - NN, LSTM/GRU, Attention
#
# Image:
#   - CNN
#   - 增强augmentation，rotate图片生成新图片，加noise, etc.
#
# ------------------------
#
# EDA
#   - domain knowledge, check data isIntuitive, how data generated
#   - anonymized, try decode, guess type
#   - plot
#
# --------------------
#
# Split
#   - K-Fold
#   - Strafication, preserve fold dist., for unbalanced.
#
#   - Time, 分trend还是 prev-next情况
#
# ------------------
#
# leakage
#   - Time
#   - Ids, metadata, row order
#   - LB probing
#
# -------------------
#
# loss, metrics
#   - MSE/RMSE, outliers meaningful;     best-constant: mean
#   - MAE, outliers no;    median
#   - MS(P)E, MA(P)E, percentage;  weighted mean
#   - (R)MS(L)E, take log; weighted mean in log space
#   - Acuracy
#   - Logloss;    freq in that class
#   - AUC ROC;  TPR-FPR; constant,random => 0.5
#   - cohen's kappa
#   - hinge loss
#
# ------------------
#
# mean encoding
#   - carefully on train-dev
#
# Regularization
#   - CV loop, expand mean
#
# ---------------
#
# macros, custom libname
#
# -------------
#
# PCA.fit(\[train, test\])
#
# ------------
#
# Ensemble
#   - average, weighted aver., conditional aver.
#   - bagging, same model, different SEEDs
#   - boosting; residual-based, xgboost, lightgbm, catboost
#   - stacking: use a model(simpler, modest) combine existing models; mind time-sensitiviy, diversity
#   - (deep) [stackNet](https://github.com/kaz-Anova/StackNet): for top scores must. Mind target leakage!!

# %% [markdown]
# webs, get insight of playground
#
# [tensorflow playground](https://playground.tensorflow.org/)
#
# [t-SNE playground](https://distill.pub/2016/misread-tsne/)
#
# [Vowpal Wabbit](https://github.com/VowpalWabbit/vowpal_wabbit)
